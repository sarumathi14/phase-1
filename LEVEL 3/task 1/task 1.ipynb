# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
data = np.array([10, 12, 12, 13, 12, 14, 13, 15, 100, 12, 14, 13, 12, 11, 200])
plt.figure(figsize=(8, 6))
plt.boxplot(data, vert=False)
plt.title("Boxplot to Identify Outliers")
plt.xlabel("Values")
plt.show()
z_scores = np.abs(stats.zscore(data))
outliers_z = data[z_scores > 3]
print("Outliers identified using Z-Score Method:", outliers_z)
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_iqr = data[(data < lower_bound) | (data > upper_bound)]
print("Outliers identified using IQR Method:", outliers_iqr)
# Out:
# Outliers identified using Z-Score Method: [200]
# Outliers identified using IQR Method: [100 200]
