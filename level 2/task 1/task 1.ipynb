# %%
import pandas as pd

# Use double backslashes or raw string to avoid escape sequence issues
df = pd.read_csv(r'c:\Users\sarum\OneDrive\Desktop\data.txt', delimiter='\t')  # Assuming the file is tab-delimited
print(df.head())
# Out:
#         Name,Age,City
# 0   Alice,30,New York
# 1  Bob,25,Los Angeles
# 2  Charlie,35,Chicago
# 3    Diana,28,Houston
