# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
titanic = sns.load_dataset('titanic')
def perform_eda(df):
    """Perform exploratory data analysis on Titanic dataset"""
    print("=== Summary Statistics ===")
    print("\nBasic Statistics:")
    print(df[['age', 'fare']].describe())
    print("\nSurvival Rate by Passenger Class:")
    survival_by_class = df.groupby('class')['survived'].mean().reset_index()
    print(survival_by_class)
    plt.figure(figsize=(8, 5))
    sns.barplot(x='class', y='survived', data=df, order=['First', 'Second', 'Third'], ci=None)
    plt.title('Survival Rate by Passenger Class')
    plt.xlabel('Passenger Class')
    plt.ylabel('Survival Rate')
    plt.ylim(0, 1)
    plt.show()
perform_eda(titanic)
# Out:
# === Summary Statistics ===
#
# Basic Statistics:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200
#
# Survival Rate by Passenger Class:
#     class  survived
# 0   First  0.629630
# 1  Second  0.472826
# 2   Third  0.242363
# C:\Users\sarum\AppData\Local\Temp\ipykernel_12092\1793916612.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_by_class = df.groupby('class')['survived'].mean().reset_index()
# C:\Users\sarum\AppData\Local\Temp\ipykernel_12092\1793916612.py:22: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='class', y='survived', data=df, order=['First', 'Second', 'Third'], ci=None)
