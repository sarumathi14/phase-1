# %%
pip install apache-airflow-providers-postgres pandas scikit-learn mlxtend
# Out:
# Collecting apache-airflow-providers-postgres
#   Downloading apache_airflow_providers_postgres-6.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pandas in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.6.1)
# Requirement already satisfied: mlxtend in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.23.4)
# Requirement already satisfied: apache-airflow>=2.10.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-postgres) (2.10.5)
# Requirement already satisfied: apache-airflow-providers-common-sql>=1.23.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-postgres) (1.25.0)
# Requirement already satisfied: psycopg2-binary>=2.9.9 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-postgres) (2.9.10)
# Collecting asyncpg>=0.30.0 (from apache-airflow-providers-postgres)
#   Downloading asyncpg-0.30.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.15.2)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.6.2)
# Requirement already satisfied: asgiref>=2.3.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.8.1)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (25.3.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.9.0)
# Requirement already satisfied: colorlog>=6.8.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (6.9.0)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.2)
# Requirement already satisfied: connexion<3.0,>=2.14.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from connexion[flask]<3.0,>=2.14.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.14.2)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.4.5)
# Requirement already satisfied: croniter>=2.0.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (6.0.0)
# Requirement already satisfied: cryptography>=41.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (44.0.2)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.2.18)
# Requirement already satisfied: dill>=0.2.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.3.9)
# Requirement already satisfied: flask-caching>=2.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.3.1)
# Requirement already satisfied: flask-session<0.6,>=0.4.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.5.0)
# Requirement already satisfied: flask-wtf>=1.1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.2.2)
# Requirement already satisfied: flask<2.3,>=2.2.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.2.5)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2025.3.2)
# Requirement already satisfied: google-re2>=1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.1.20240702)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (23.0.0)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.28.1)
# Requirement already satisfied: importlib_metadata>=6.5 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (8.6.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.2.0)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.1.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.23.0)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.10.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.0.3)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.12.2)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.0.0)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.0.2)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.1.1)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.4.2)
# Requirement already satisfied: methodtools>=0.4.7 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.4.7)
# Requirement already satisfied: opentelemetry-api>=1.24.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.24.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: packaging>=23.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.12.1)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.0.0)
# Requirement already satisfied: pluggy>=1.5.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.5.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (7.0.0)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.19.1)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.10.1)
# Requirement already satisfied: python-daemon>=3.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.1.2)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.16.0)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (8.0.4)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.4.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.0.0)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.1.4)
# Requirement already satisfied: rich-argparse>=1.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.7.0)
# Requirement already satisfied: rich>=12.4.4 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (13.9.4)
# Requirement already satisfied: setproctitle>=1.3.3 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.3.5)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.36 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.4.54)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.0.2)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.9.0)
# Requirement already satisfied: tenacity!=8.2.0,>=8.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (9.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.0.1)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.2.6)
# Requirement already satisfied: werkzeug<3,>=2.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.2.3)
# Requirement already satisfied: apache-airflow-providers-common-compat in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.6.0)
# Requirement already satisfied: apache-airflow-providers-common-io in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.5.2)
# Requirement already satisfied: apache-airflow-providers-fab>=1.0.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.5.3)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.12.3)
# Requirement already satisfied: apache-airflow-providers-http in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (5.2.1)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.8.3)
# Requirement already satisfied: apache-airflow-providers-smtp in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.0.2)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.0.1)
# Requirement already satisfied: sqlparse>=0.5.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-common-sql>=1.23.0->apache-airflow-providers-postgres) (0.5.3)
# Requirement already satisfied: more-itertools>=9.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-common-sql>=1.23.0->apache-airflow-providers-postgres) (10.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: Mako in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic<2.0,>=1.13.1->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic<2.0,>=1.13.1->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.13.2)
# Requirement already satisfied: flask-appbuilder==4.5.3 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.5.3)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.6.3)
# Requirement already satisfied: jmespath>=0.7.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.0.1)
# Requirement already satisfied: apispec<7,>=6.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apispec[yaml]<7,>=6.0.0->flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (6.8.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.4.6)
# Requirement already satisfied: click<9,>=8 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (8.1.8)
# Requirement already satisfied: email-validator>=1.0.5 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.2.0)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.0.0)
# Requirement already satisfied: Flask-Limiter<4,>3 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.12)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.5.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.7.1)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.26.1)
# Requirement already satisfied: marshmallow-sqlalchemy<0.29.0,>=0.22.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.28.2)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.2.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.41.2)
# Requirement already satisfied: WTForms<4 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.2.1)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from connexion<3.0,>=2.14.2->connexion[flask]<3.0,>=2.14.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from connexion<3.0,>=2.14.2->connexion[flask]<3.0,>=2.14.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (6.0.2)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from connexion<3.0,>=2.14.2->connexion[flask]<3.0,>=2.14.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.5.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=41.0.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecated>=1.2.13->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.17.2)
# Requirement already satisfied: cachelib>=0.9.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask-caching>=2.0.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.13.0)
# Requirement already satisfied: anyio in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.9.0)
# Requirement already satisfied: certifi in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.0.8)
# Requirement already satisfied: idna in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.25.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib_metadata>=6.5->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.18.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.24.0)
# Requirement already satisfied: uc-micro-py in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from linkify-it-py>=2.0.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.1.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.1.2)
# Requirement already satisfied: wirerope>=0.4.7 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from methodtools>=0.4.7->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.32.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.32.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.69.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: opentelemetry-proto==1.32.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: opentelemetry-sdk~=1.32.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.32.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-proto==1.32.0->opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (5.29.4)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-slugify>=5.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.27.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.27.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy<2.0,>=1.4.36->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.1.1)
# Requirement already satisfied: aiohttp!=3.11.0,>=3.9.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (3.11.16)
# Requirement already satisfied: aiosqlite>=0.20.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from apache-airflow-providers-sqlite->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.21.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=3.11.0,>=3.9.2->apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=3.11.0,>=3.9.2->apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=3.11.0,>=3.9.2->apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=3.11.0,>=3.9.2->apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=3.11.0,>=3.9.2->apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=3.11.0,>=3.9.2->apache-airflow-providers-http->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.19.0)
# Requirement already satisfied: pycparser in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.22)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx>=0.25.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (1.3.1)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from email-validator>=1.0.5->flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.7.0)
# Requirement already satisfied: Babel>=2.3 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (2.17.0)
# Requirement already satisfied: limits>=3.13 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.7.3)
# Requirement already satisfied: ordered-set<5,>4 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.3->apache-airflow-providers-fab>=1.0.2->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b0 in c:\users\sarum\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk~=1.32.0->opentelemetry-exporter-otlp-proto-grpc==1.32.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow>=2.10.0->apache-airflow-providers-postgres) (0.53b0)
# Downloading apache_airflow_providers_postgres-6.2.1-py3-none-any.whl (18 kB)
# Downloading asyncpg-0.30.0-cp311-cp311-win_amd64.whl (629 kB)
#    ---------------------------------------- 0.0/629.4 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/629.4 kB 991.0 kB/s eta 0:00:01
#    ----------- ---------------------------- 184.3/629.4 kB 1.9 MB/s eta 0:00:01
#    ------------- -------------------------- 215.0/629.4 kB 1.9 MB/s eta 0:00:01
#    -------------- ------------------------- 235.5/629.4 kB 1.2 MB/s eta 0:00:01
#    -------------------- ------------------- 317.4/629.4 kB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 378.9/629.4 kB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 378.9/629.4 kB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 501.8/629.4 kB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 532.5/629.4 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 593.9/629.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 629.4/629.4 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: asyncpg, apache-airflow-providers-postgres
# Successfully installed apache-airflow-providers-postgres-6.2.1 asyncpg-0.30.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\sarum\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from datetime import datetime, timedelta
from airflow import DAG
from airflow.operators.python import PythonOperator
from airflow.providers.postgres.hooks.postgres import PostgresHook
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

default_args = {
    'owner': 'airflow',
    'depends_on_past': False,
    'start_date': datetime(2023, 1, 1),
    'email_on_failure': False,
    'email_on_retry': False,
    'retries': 1,
    'retry_delay': timedelta(minutes=5),
}

def extract_transaction_data():
    """Simulate extracting raw transaction data"""
    # In production, this would connect to your actual data source
    data = {
        'transaction_id': [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008],
        'user_id': [101, 102, 101, 103, 102, 104, 101, 103],
        'product_id': ['P1', 'P2', 'P3', 'P1', 'P4', 'P2', 'P4', 'P3'],
        'amount': [120.50, 35.99, 89.99, 120.50, 45.75, 35.99, 45.75, 89.99],
        'timestamp': [
            '2023-11-01 09:15:23', '2023-11-01 11:30:45',
            '2023-11-02 14:20:10', '2023-11-02 16:45:30',
            '2023-11-03 10:10:00', '2023-11-03 12:30:15',
            '2023-11-04 15:45:20', '2023-11-04 18:00:00'
        ]
    }
    df = pd.DataFrame(data)
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    return df.to_json()

def calculate_clv(**kwargs):
    """Calculate Customer Lifetime Value"""
    ti = kwargs['ti']
    data = ti.xcom_pull(task_ids='extract_transaction_data')
    df = pd.read_json(data)
    
    # Calculate CLV (simplified version)
    clv = df.groupby('user_id').agg(
        total_spend=('amount', 'sum'),
        purchase_count=('transaction_id', 'count'),
        avg_purchase_value=('amount', 'mean')
    ).reset_index()
    
    # Add customer segmentation
    kmeans = KMeans(n_clusters=3)
    clv['segment'] = kmeans.fit_predict(clv[['total_spend', 'purchase_count']])
    clv['segment'] = clv['segment'].map({0: 'Low', 1: 'Medium', 2: 'High'})
    
    # Save to database
    hook = PostgresHook(postgres_conn_id='postgres_conn')
    conn = hook.get_conn()
    clv.to_sql('customer_clv', conn, if_exists='replace', index=False)
    conn.close()

def analyze_time_trends(**kwargs):
    """Analyze hourly/daily purchase patterns"""
    ti = kwargs['ti']
    data = ti.xcom_pull(task_ids='extract_transaction_data')
    df = pd.read_json(data)
    
    # Extract time features
    df['hour'] = df['timestamp'].dt.hour
    df['day_of_week'] = df['timestamp'].dt.day_name()
    
    # Time-based analysis
    hourly_trends = df.groupby('hour').agg(
        transaction_count=('transaction_id', 'count'),
        total_sales=('amount', 'sum')
    ).reset_index()
    
    daily_trends = df.groupby('day_of_week').agg(
        transaction_count=('transaction_id', 'count'),
        total_sales=('amount', 'sum')
    ).reset_index()
    
    # Save to database
    hook = PostgresHook(postgres_conn_id='postgres_conn')
    conn = hook.get_conn()
    hourly_trends.to_sql('hourly_trends', conn, if_exists='replace', index=False)
    daily_trends.to_sql('daily_trends', conn, if_exists='replace', index=False)
    conn.close()

def analyze_product_affinity(**kwargs):
    """Identify frequently bought together products"""
    ti = kwargs['ti']
    data = ti.xcom_pull(task_ids='extract_transaction_data')
    df = pd.read_json(data)
    
    # Prepare data for association rules
    basket = df.groupby(['transaction_id', 'product_id'])['amount'] \
              .sum().unstack().reset_index().fillna(0) \
              .set_index('transaction_id')
    
    # Convert to binary matrix
    basket = basket.applymap(lambda x: 1 if x > 0 else 0)
    
    # Find frequent itemsets
    frequent_itemsets = apriori(basket, min_support=0.1, use_colnames=True)
    
    # Generate association rules
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
    rules = rules.sort_values('confidence', ascending=False)
    
    # Save to database
    hook = PostgresHook(postgres_conn_id='postgres_conn')
    conn = hook.get_conn()
    rules.to_sql('product_affinity_rules', conn, if_exists='replace', index=False)
    conn.close()

with DAG(
    'ecommerce_behavior_analytics',
    default_args=default_args,
    description='ETL pipeline for e-commerce customer behavior analytics',
    schedule_interval='@daily',
    catchup=False,
) as dag:
    
    
    
    extract_data = PythonOperator(
        task_id='extract_transaction_data',
        python_callable=extract_transaction_data
    )
    
    clv_analysis = PythonOperator(
        task_id='calculate_clv',
        python_callable=calculate_clv
    )
    
    time_analysis = PythonOperator(
        task_id='analyze_time_trends',
        python_callable=analyze_time_trends
    )
    
    product_analysis = PythonOperator(
        task_id='analyze_product_affinity',
        python_callable=analyze_product_affinity
    )
# Out:
# C:\Users\sarum\AppData\Local\Temp\ipykernel_14864\2053445118.py:118 RemovedInAirflow3Warning: Param `schedule_interval` is deprecated and will be removed in a future release. Please use `schedule` instead.
